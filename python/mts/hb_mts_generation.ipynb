# %% [markdown]
# <h1 style="color:rgb(0,162,219); font-family:Arial; font-size:48px;"> WP4
#     Home-based Mode-Time Split Improvements </h1>

# %% [markdown]
# <p style="color:rgb(0,162,219); font-family:Arial; font-size:16px;">Notebook Information </p>
#
# <table style="color:rgb(88,89,91); font-family:Arial; float:left; font-size:13px; text-align:left;">
#     <tr>
#         <td style="color:rgb(0,90,132);font-size:13px; text-align:left;"><b>Project</b></td>
#         <td style="text-align:left;">NorMITs Demand Partner </td>
#     </tr>
#     <tr>
#         <td style="color:rgb(0,90,132);font-size:13px; text-align:left;"><b>Primary Contact Name</b></td>
#         <td style="text-align:left;">Annie Simcock </td>
#     </tr>
#     <tr>
#         <td style="color:rgb(0,90,132);font-size:13px; text-align:left;"><b>Primary Contact Email</b></td>
#         <td style="text-align:left;">Anne-Marie.Simcock@atkinsrealis.com </td>
#     </tr>
#     <tr>
#         <td style="color:rgb(0,90,132);font-size:13px; text-align:left;"><b>Document Sensitivity</b></td>
#         <td style="text-align:left;"> </td>
#     </tr>
# </table>

# %% [markdown]
# <p style="color:rgb(0,162,219); font-family:Arial; font-size:16px;"> Summary </p>

# %% [markdown]
# This Notebook contains the methodology and implementation for deriving the home-based mode-time splits within the mdloutput.py script using aggregated National Travel Survey data from the classified build. The current method uses the agg_fill function defined in the mdlbuild.py. Within this function, the mode-time splits are calculated via a sample size row-wise criteria i.e., each datapoint at the purpose, household type, area type, mode, time period level is considered per a 300 trips threshold and the row is then handled accordingly in one of three ways (either calculated by the raw trips split, household type trips aggregation or TfN area type trips aggregation.
#
# The limitations of the current method are:
#
# - There is inconsistency in approach, for a given purpose, tfn area type, household type combination, individual mode-time splits can be derived by separate methods.
# - There is no indication in the mode-time split (mts) outputs as to which method was applied to derive each mts.
# - As a result of the approach, each purpose, tfn area type, household type combination does not add to 1. This will cause problems in downstream applications.
# - Due to the new TfN area type update (up to 20 types), the current method only refers to area types 1-14 and therefore this is no longer appropriate and should be updated to better reflect the new area type definition
# - There are inconsistencies in naming conventions between home-based and non-home-based mts outputs. For the home based MTS, this column is called 'splits', and for the non-home based MTS, the column is called 'rho'.
#
# The WP4_EDA Notebook provides more information into the investigation of the mts outputs.
#
# This new approach aims to improve the process by implementing the following features:
#
# - Most importantly, ensure that the mode-time splits for each purpose, tfn area type and household type are constrained to 1.
# - Build a model that applies the same method to each 'block' of purpose, tfn area type and household type.
# - Add an audit trail column to the mts outputs that outlines which data aggregation method was used to derive the mode-time plits for each block
# - Determine a proportionate trips threshold to use to define the cut off for each aggregation method.
# - Define and implementation suitable aggregations of TfN area types for all 20 new TfN area types.
# - Consistency in naming convention of the 'splits' column taken forward into non-home-based implementation

# %% [markdown]
# <table style="color:rgb(88,89,91); font-family:Arial; float:left; font-size:13px; text-align:left;">
#     <tr>
#         <th style="color:rgb(0,90,132); text-align:left;">Version</th>
#         <th style="color:rgb(0,90,132); text-align:left;">Originated</th>
#         <th style="color:rgb(0,90,132); text-align:left;">Date</th>
#         <th style="color:rgb(0,90,132); text-align:left;">Comments</th>
#         <th style="color:rgb(0,90,132); text-align:left;">Checked</th>
#         <th style="color:rgb(0,90,132); text-align:left;">Date</th>
#         <th style="color:rgb(0,90,132); text-align:left;">Comments</th>
#     </tr>
#     <tr>
#     <tr>
#         <td style="text-align:left;">v0.1</td>
#         <td style="text-align:left;">AS</td>
#         <td style="text-align:left;">10/04/2024</td>
#         <td style="text-align:left;">Originator, added initial model build, hh only build and then the full model with tfn_at aggregatation with visualisations.</td>
#         <td style="text-align:left;">RM </td>
#         <td style="text-align:left;">23/05/2024</td>
#         <td style="text-align:left;"> </td>
#     <tr>
#         <td style="text-align:left;">v0.2</td>
#         <td style="text-align:left;">AS</td>
#         <td style="text-align:left;">23/04/2024</td>
#         <td style="text-align:left;">Addressing comments</td>
#         <td style="text-align:left;"></td>
#         <td style="text-align:left;"></td>
#         <td style="text-align:left;"> </td>
#     </tr>
#     <tr>
#         <td style="text-align:left;"> </td>
#         <td style="text-align:left;"> </td>
#         <td style="text-align:left;"> </td>
#         <td style="text-align:left;"> </td>
#         <td style="text-align:left;"> </td>
#         <td style="text-align:left;"> </td>
#         <td style="text-align:left;"> </td>
#     </tr>
#     <tr>
#         <td style="text-align:left;"> </td>
#         <td style="text-align:left;"> </td>
#         <td style="text-align:left;"> </td>
#         <td style="text-align:left;"> </td>
#         <td style="text-align:left;"> </td>
#         <td style="text-align:left;"> </td>
#         <td style="text-align:left;"> </td>
#     </tr>
#     <tr>
#         <td style="text-align:left;"> </td>
#         <td style="text-align:left;"> </td>
#         <td style="text-align:left;"> </td>
#         <td style="text-align:left;"> </td>
#         <td style="text-align:left;"> </td>
#         <td style="text-align:left;"> </td>
#         <td style="text-align:left;"> </td>
#     </tr>
#     <tr>
#         <td style="text-align:left;"> </td>
#         <td style="text-align:left;"> </td>
#         <td style="text-align:left;"> </td>
#         <td style="text-align:left;"> </td>
#         <td style="text-align:left;"> </td>
#         <td style="text-align:left;"> </td>
#         <td style="text-align:left;"> </td>
#     </tr>
# </table>

# %% [markdown]
# <p style="color:rgb(0,162,219); font-family:Arial; font-size:16px;">Contents </p>

# %% [markdown]
# [1. Preliminaries and Inputs](#Preliminaries-and-Inputs)<br>
# [2. Pre-Processing Steps](#Pre-Processing-Steps)<br>
# [3. Model Information](#Model-Information)<br>
# [4. Initial Model Build](#Initial-Model-Build)<br>
# [5. Refined Model Build](#Refined-Model-Build)<br>
# [6. Full Model Build](#Full-Model-Build)<br>

# %% [markdown]
# ## Preliminaries and Inputs

# %% [markdown]
# This section imports the python packages which are required and reads in the input to the agg_fill function which is our starting point.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split, cross_val_predict
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
#read in the dataframe which is the input into agg_fill
df = pd.read_csv('dfr_split_before.csv')
df = df[['purpose','tfn_at','hh_type','mode','period','trips']]

# %% [markdown]
# ## Pre-Processing Steps

# %% [markdown]
# This section removes mode 8 (air travel) from the trips dataframe as agreed due to low to no trip sample.
#
# At the p,at,hh level, we sum over the trips column to calculate a total number of trips for this 'block'. We use this to calculate the raw proportion of trips (split) that is asscociated with each mode-time period combination to create the 'split' column.
#
# Based on the total trips at each p,at,hh level we assign the split_method column based on whether the total trips is above or below 500 trips. If trips>500 we assign the split method as 'observed' indicating that we will using the observed mts, otherwise we assign 'TBD' as the split needs to be determined via the modelling process.
#
# Please consult the EDA notebook for analysis on the distribution of total trips per p,at,hh block above 500. This justifies the use of the 500 trip threshold.

# %%
#The decision to remove mode 8 (air travel) from the mode was made.
df = df[df['mode'] != 8] 
#calculate the total trips at the p,at,hh level
df_total = df.groupby(['purpose','tfn_at','hh_type']).sum()
df_total = df_total[['trips']].reset_index()

#determine whether the combination needs to be modelled or the raw splits can be used, if trips>500 use observed trips to derive splits
df_total['split_method'] = np.where(df_total.trips>=500, 'observed', 'TBD')
df_total = df_total.rename(columns={'trips': 'total_trips'})
#calculate the raw split (trips/(total trips at the p,at,hh level))
df_trip_join = pd.merge(df, df_total, left_on =['purpose','tfn_at','hh_type'] , right_on = ['purpose','tfn_at','hh_type'], how='inner')
df_trip_join['split'] = df_trip_join['trips'] / df_trip_join['total_trips']
df_trip_join = df_trip_join[['purpose','tfn_at','hh_type','mode', 'period','split','trips','total_trips','split_method']]
df_trip_join['mode_period'] = df_trip_join['mode'].astype(str) + '_' + df_trip_join['period'].astype(str)
df_trip_join.to_csv('trip_join.csv')
df_trip_join
# Out:
#        purpose  tfn_at  hh_type  mode  period     split       trips  \
# 0            1       1        1     1       1  0.156316  584.720240
# 1            1       1        1     1       2  0.019467   72.817530
# 2            1       1        1     1       3  0.003976   14.873738
# 3            1       1        1     1       4  0.017804   66.598320
# 4            1       1        1     1       5  0.009405   35.179843
# ...        ...     ...      ...   ...     ...       ...         ...
# 53755        8      20        8     7       2  0.003616    1.319658
# 53756        8      20        8     7       3  0.000000    0.000000
# 53757        8      20        8     7       4  0.000000    0.000000
# 53758        8      20        8     7       5  0.000000    0.000000
# 53759        8      20        8     7       6  0.000000    0.000000
#
#        total_trips split_method mode_period
# 0      3740.618998     observed         1_1
# 1      3740.618998     observed         1_2
# ...

# %% [markdown]
# ## Model Information

# %% [markdown]
# ### Modelling Approach
# The approach is to calculate the mode-time splits via a sample size “block”-wise criteria i.e., total trips across a single purpose, household type, area type are considered per a threshold and the “block” is then handled accordingly.
#
# In instances where total trips for the block are above the threshold, we assume that a low number of trips for a mode-time combination within the block indicates that this combination isn’t popular (rather than there being low sample size for that specific mode-time).
#
# - For trips above threshold we calculate mode-time split directly off the datapoints for that block.
#
# - For total trips below threshold, we combine the blocks using aggregation hierarchy i.e., by similar household types and area types.
#
# We build a model using multiple datapoints per mode-time combination to give a synthetic trip/split profile to calculate mode-time split from.
#
#
# ### Purpose of the model
# The purpose of the model is to create a synthetic profile for the mode-time splits for combinations of purpose, TfN area type and household type where the NTS trips sample is below a threshold. To do this we need to use aggregation hierarchy of household type or TfN area type to build a combined profile of mode-time splits.
#
# This requires us to filter down to the relevant purpose, TfN area type level as including other combinations of these would impact the profile and may not be representative of the combination we are looking to model. The biggest factor is purpose, adding in different purposes into the training dataset makes the mts much higher or lower than the individual datapoints.
#
# After conducting an investigation to determine the best model form to approach this problem we have chosen to use linear regression model to 'fit' the trip proportions/splits of similar household types or TfN area types. Other alogrithms and ML approaches have been considered and ruled out based on suitability, proportionality and success model fitting in inital model builds. A main factor in this decision is the shape and size of the dataset (number of features to the number of datapoints) and the proportionality of the approach to the problem.
#
# Weighting against blocks which have a larger sample of trips has been considered within this work package and discussions have been conducted. At this time, no decision has been taken to implement this in the model build due to caution raised about  adding bias into the process.

# %% [markdown]
# ## Initial Model Build

# %% [markdown]
# A model that loops through p, at combinations and for each hh type calculates the synthetic profile of mode-time splits based on the following aggregated household types.
#
# These synthethic mode-time splits can then be applied to combinations that suffer with low sample size.
#
# This implementation does not include 500 trips threshold logic.

# %%
df_trip_join = df_trip_join.fillna(0) #ensure that the target variable y (splits) always has a value
#create an array of arrays
list_hh_type = [[1,3,6], [2,5,8], [4,7]]
modelled_df = pd.DataFrame()

for p in range(1,9):
    for at in range (1,21):
        for hh in list_hh_type:
            df_hh = df_trip_join[df_trip_join.hh_type.isin(hh)]
            df_mode_period_join_f = df_hh[(df_hh['purpose']==p) &(df_hh['tfn_at']==at)]
            needs_pred = df_mode_period_join_f[df_mode_period_join_f.split_method == 'TBD']

            if not needs_pred.empty:
                X_train_cat = df_mode_period_join_f[['purpose', 'tfn_at','mode_period']]
                X_train_prob = df_mode_period_join_f[['split']]

                # Encode categorical features using one-hot encoding
                encoder = OneHotEncoder(sparse_output=False)
                X = encoder.fit_transform(X_train_cat)

                y = X_train_prob['split'].reset_index()
                y = np.array([y['split']]).T

                # Perform LOOCV to determine the best model
                mse_scores = []
                models = []
                for i in range(len(X)):
                    # Create training data without the ith sample
                    X_train = np.delete(X, i, axis=0)
                    y_train = np.delete(y, i)

                    # Initialize and train the model
                    model = LinearRegression()
                    model.fit(X, y)
                    models.append(model)

                    # Predict on the ith sample
                    y_pred = model.predict(X[i].reshape(1, -1))

                    # Calculate mean squared error
                    mse_score = (y[i] - y_pred)**2

                    mse_scores.append(mse_score)
                
                # Select the index of the best model based on the minimum MSE
                best_model_index = np.argmin(mse_scores)
                best_model = models[best_model_index]

                X_predictor = encoder.fit_transform(X_train_cat.drop_duplicates())
                y_predicted_new_data = best_model.predict(X_predictor)
                
                m_p = X_train_cat.drop_duplicates()[['mode_period']]     

                df_predict = pd.DataFrame(y_predicted_new_data)
                df_model = df_predict.rename(columns={0: 'modelled'})
                df_model = df_model.clip(lower = 0)

                df_model['purpose'] = p
                df_model['tfn_at'] = at
                df_model = df_model.reset_index()
                m_p = m_p.reset_index()
                df_model['mode_period'] = m_p['mode_period']
                # store DataFrame in list
                df_model['split_method'] =str(hh)
                #store df 
                modelled_df= pd.concat([modelled_df, df_model])
                
                
#add column describing the method used to derive the splits
modelled_df['modelled'] = modelled_df['modelled'].clip(lower = 0)
modelled_df = modelled_df[['mode_period','purpose','tfn_at','modelled', 'split_method']]
modelled_df_groupby = modelled_df.groupby(['purpose','tfn_at']).sum().rename(columns={'modelled': 'sum of modelled'}).reset_index()

#constraining the mts to 1 to created the adjusted rho column
all_modelled_df = pd.merge(modelled_df, modelled_df_groupby, how='inner', on = ['purpose','tfn_at'])
all_modelled_df['adjusted_rho'] = all_modelled_df['modelled'] / all_modelled_df['sum of modelled']
all_modelled_df = all_modelled_df[['mode_period','purpose','tfn_at', 'split_method', 'adjusted_rho']]
all_modelled_df = all_modelled_df.fillna(0)

#create the split column that defined which hh type agg method would be needed
df_trip_join_hh = df_trip_join[['purpose','tfn_at','mode_period','hh_type', 'split', 'split_method']]
df_trip_join_hh['split_m'] = np.where((df_trip_join_hh['hh_type'] == 1)| (df_trip_join_hh['hh_type'] == 3)| (df_trip_join_hh['hh_type'] == 6), str([1,3,6]), (np.where((df_trip_join_hh['hh_type'] == 2)| (df_trip_join_hh['hh_type'] == 5)| (df_trip_join_hh['hh_type'] == 8), str([2,5,8]), str([4,7]))))
df_trip_join_hh = df_trip_join_hh.rename(columns={'split_method': 'split_needed'})

#merge the observed and modelled information together into a final dataframe
resultant_df = pd.merge(df_trip_join_hh, all_modelled_df, left_on=['purpose', 'tfn_at','mode_period','split_m'], right_on=['purpose', 'tfn_at','mode_period','split_method'], how = 'left')
resultant_df['split_final'] = np.where(resultant_df['split_needed'] == 'TBD', resultant_df['adjusted_rho'], resultant_df['split'])
resultant_df
# Out:
# C:\Users\SIMC2320\AppData\Local\Temp\ipykernel_25756\730983317.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_trip_join_hh['split_m'] = np.where((df_trip_join_hh['hh_type'] == 1)| (df_trip_join_hh['hh_type'] == 3)| (df_trip_join_hh['hh_type'] == 6), str([1,3,6]), (np.where((df_trip_join_hh['hh_type'] == 2)| (df_trip_join_hh['hh_type'] == 5)| (df_trip_join_hh['hh_type'] == 8), str([2,5,8]), str([4,7]))))
#        purpose  tfn_at mode_period  hh_type     split split_needed    split_m  \
# 0            1       1         1_1        1  0.156316     observed  [1, 3, 6]
# 1            1       1         1_2        1  0.019467     observed  [1, 3, 6]
# 2            1       1         1_3        1  0.003976     observed  [1, 3, 6]
# ...

# %% [markdown]
# ### Visualisation of modelled approach

# %% [markdown]
# We can plot the synthetic mode-time split profiles for any combinations which requires modelling as shown below.
#
# The adjusted split value lies within the observed datapoints demonstrating that the model is able to 'fit' the existing datapoints well.

# %%
p=1
at=3
list_hh_type = [[1,3,6], [2,5,8], [4,7]]
for hh in list_hh_type:
    df_hh = df_trip_join[df_trip_join.hh_type.isin(hh)]
    df_mode_period_join_f = df_hh[(df_hh['purpose']==p) &(df_hh['tfn_at']==at)]
    #create the dataframe which has the observed splits to compare against
    comparison_df = df_mode_period_join_f.pivot_table(index=['purpose','tfn_at','hh_type'], columns='mode_period', values='split', aggfunc='sum', fill_value=0).reset_index()
    pivot_df_T = comparison_df.T.reset_index().loc[3::]
    pivot_df_T['purpose'] = p
    pivot_df_T['tfn_at'] = at
    df_model = all_modelled_df[(all_modelled_df['purpose']==p) &(all_modelled_df['tfn_at']==at) &(all_modelled_df['split_method']==str(hh))]
    if not df_model.empty:
        join_model_obs = pd.concat([pivot_df_T.reset_index(), df_model.reset_index()['adjusted_rho']], axis=1)

        if len(hh)>2:
            join_model_obs = join_model_obs.rename(columns={0: 'hh_type_' + str(hh[0])})
            join_model_obs = join_model_obs.rename(columns={1: 'hh_type_' + str(hh[1])})
            join_model_obs = join_model_obs.rename(columns={2: 'hh_type_' + str(hh[2])})  
            join_model_obs = join_model_obs[['mode_period', 'hh_type_' + str(hh[0]), 'hh_type_' + str(hh[1]), 'hh_type_' + str(hh[2]), 'adjusted_rho']]
        else:    
            join_model_obs = join_model_obs.rename(columns={0: 'hh_type_' + str(hh[0])})
            join_model_obs = join_model_obs.rename(columns={1: 'hh_type_' + str(hh[1])})
            join_model_obs = join_model_obs[['mode_period', 'hh_type_' + str(hh[0]), 'hh_type_' + str(hh[1]), 'adjusted_rho']]

        #plot the observed vs modelled
        dfm = pd.melt(join_model_obs, id_vars="mode_period", var_name="number", value_name="prob")

        sns.set(style="whitegrid")
        plt.figure(figsize=(8, 5))
        ax = sns.scatterplot(x='mode_period', y='prob', hue='number', data=dfm)
        ax.spines[['top', 'right']].set_visible(False)
        sns.move_legend(ax, bbox_to_anchor=(1, 0.5), loc='center left', frameon=False)

# %% [markdown]
# ## Refined Model Build

# %% [markdown]
# ## Household type aggregation only
# A model that loops through purpose, TfN area type and household type combinations and creates a synthetic profile of mode-time splits for the combinations that have a total number of trips less than 500 (defined by the split_method ==TBD). The profiles are built on similar household types if the total combined trips of all similar households are also above 500.
#
# Still to do: If the aggregated household total trips are still less than 500, we use data from similar TfN area types in addition to similar household types which adds more datapoints to the training dataset.

# %%
df_trip_join = df_trip_join.fillna(0) #ensure that the target variable y (splits) always has a value
#create an array of arrays
tfn_at = {1: [1,2], 2: [1,2], 3: [3,4,5], 4: [3,4,5], 5: [3,4,5], 6: [6,7], 7: [6,7], 8: [8,9], 9: [8,9],10: [10,11,12], 11: [10,11,12],12: [10,11,12],13: [13,14], 14: [13,14]}
list_hh_type = [[1,3,6], [2,5,8], [4,7]]
modelled_df = pd.DataFrame()
audit_df = pd.DataFrame(columns = ['purpose', 'area_type','hh_agg', 'total_trips', 'status'])
for p in range(1,9):
    for at in range (1,21):
        df_mode_period_join_f = df_trip_join[(df_trip_join['purpose']==p) &(df_trip_join['tfn_at']==at)]
        for hh in list_hh_type:
            df_mode_period_join_hh = df_mode_period_join_f[df_mode_period_join_f.hh_type.isin(hh)]
            needs_pred = df_mode_period_join_hh[df_mode_period_join_hh.split_method == 'TBD']
            trips = df_mode_period_join_hh.total_trips.unique().sum()

            if not needs_pred.empty:
                if trips > 500:
                    data_df = [[p, at, hh, trips, 'Need hh_type aggregation']]
                    audit_df = audit_df.append(pd.Series(data_df[0], index=audit_df.columns), ignore_index=True)
                    if not needs_pred.empty:
                        X_train_cat = df_mode_period_join_hh[['purpose', 'tfn_at','mode_period']]
                        X_train_prob = df_mode_period_join_hh[['split']]

                        # Encode categorical features using one-hot encoding
                        encoder = OneHotEncoder(sparse_output=False)
                        X = encoder.fit_transform(X_train_cat)

                        y = X_train_prob['split'].reset_index()
                        y = np.array([y['split']]).T

                        # Initialize and train the model
                        model = LinearRegression()
                        model.fit(X, y)

                        X_predictor = encoder.fit_transform(X_train_cat.drop_duplicates())
                        y_predicted_new_data = model.predict(X_predictor)

                        m_p = X_train_cat.drop_duplicates()[['mode_period']]

                        df_predict = pd.DataFrame(y_predicted_new_data)
                        df_model = df_predict.rename(columns={0: 'modelled'})
                        df_model = df_model.clip(lower = 0)

                        df_model['purpose'] = p
                        df_model['tfn_at'] = at
                        df_model = df_model.reset_index()
                        m_p = m_p.reset_index()
                        df_model['mode_period'] = m_p['mode_period']
                        # store DataFrame in list
                        df_model['split_method'] =str(hh)
                        #store df 
                        modelled_df= pd.concat([modelled_df, df_model])               
                else:
                    data_df = [[p, at, hh, trips, 'Need tfn_at aggregation']]
                    audit_df = audit_df.append(pd.Series(data_df[0], index=audit_df.columns), ignore_index=True)
            else:
                data_df = [[p, at, hh, trips, 'No aggregation all hh types above 500 trips individually']]
                audit_df = audit_df.append(pd.Series(data_df[0], index=audit_df.columns), ignore_index=True)
#add column describing the method used to derive the splits
modelled_df['modelled'] = modelled_df['modelled'].clip(lower = 0)
modelled_df = modelled_df[['mode_period','purpose', 'tfn_at','modelled', 'split_method']]
modelled_df =modelled_df.assign(hh_type=modelled_df['split_method'].str.strip('[]').str.split(',')).explode('hh_type').reset_index(drop=True)
modelled_df.hh_type = modelled_df.hh_type.astype(int)
modelled_df_groupby = modelled_df.groupby(['purpose','tfn_at','hh_type']).sum().rename(columns={'modelled': 'sum of modelled'}).reset_index()

#constraining the mts to 1 to created the adjusted rho column
all_modelled_hh = pd.merge(modelled_df, modelled_df_groupby, how='inner', on = ['purpose','tfn_at','hh_type'])
all_modelled_hh['adjusted_rho'] = all_modelled_hh['modelled'] / all_modelled_hh['sum of modelled']
all_modelled_hh = all_modelled_hh[['mode_period','purpose','tfn_at', 'hh_type', 'split_method', 'adjusted_rho']]
all_modelled_hh = all_modelled_hh.fillna(0)
all_modelled_hh = all_modelled_hh.drop_duplicates()

#create the split column that defined which hh type agg method would be needed
df_trip_join_hh = df_trip_join[['purpose','tfn_at','mode_period','hh_type', 'split', 'split_method']]
df_trip_join_hh = df_trip_join_hh.rename(columns={'split_method': 'split_needed'})

#merge the observed and modelled information together into a final dataframe
resultant_df = pd.merge(df_trip_join_hh, all_modelled_hh, left_on=['purpose', 'tfn_at','mode_period', 'hh_type'], right_on=['purpose', 'tfn_at','mode_period','hh_type'], how = 'left')
resultant_df['split_final'] = np.where(resultant_df['split_needed'] == 'TBD', resultant_df['adjusted_rho'], resultant_df['split'])
resultant_df.to_csv('hh_only_mts_output.csv')
audit_df.to_csv('hh_only_audit_output.csv')
resultant_df.drop_duplicates()
resultant_df
# Out:
# C:\Users\SIMC2320\AppData\Local\Temp\ipykernel_25756\474685661.py:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   audit_df = audit_df.append(pd.Series(data_df[0], index=audit_df.columns), ignore_index=True)
# C:\Users\SIMC2320\AppData\Local\Temp\ipykernel_25756\474685661.py:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   audit_df = audit_df.append(pd.Series(data_df[0], index=audit_df.columns), ignore_index=True)
# C:\Users\SIMC2320\AppData\Local\Temp\ipykernel_25756\474685661.py:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   audit_df = audit_df.append(pd.Series(data_df[0], index=audit_df.columns), ignore_index=True)
# ...

# %%
audit_df
# Out:
#     purpose area_type     hh_agg   total_trips  \
# 0         1         1  [1, 3, 6]  16524.119459
# 1         1         1  [2, 5, 8]   4636.856237
# 2         1         1     [4, 7]  10553.461190
# 3         1         2  [1, 3, 6]   8607.767941
# 4         1         2  [2, 5, 8]  20339.344903
# ..      ...       ...        ...           ...
# 475       8        19  [2, 5, 8]   6601.422512
# 476       8        19     [4, 7]   1623.375816
# 477       8        20  [1, 3, 6]    387.973258
# 478       8        20  [2, 5, 8]   1370.043351
# 479       8        20     [4, 7]    986.608748
#
#                                                 status
# 0    No aggregation all hh types above 500 trips in...
# 1    No aggregation all hh types above 500 trips in...
# 2    No aggregation all hh types above 500 trips in...
# 3    No aggregation all hh types above 500 trips in...
# 4    No aggregation all hh types above 500 trips in...
# ..                                                 ...
# ...

# %% [markdown]
# #### Visualisations of the model to evaluate performance

# %%
p=1
at=3
list_hh_type = [[1,3,6], [2,5,8], [4,7]]
for hh in list_hh_type:
    df_hh = df_trip_join[df_trip_join.hh_type.isin(hh)]
    df_mode_period_join_f = df_hh[(df_hh['purpose']==p) &(df_hh['tfn_at']==at)]
    #create the dataframe which has the observed splits to compare against
    comparison_df = df_mode_period_join_f.pivot_table(index=['purpose','tfn_at','hh_type'], columns='mode_period', values='split', aggfunc='sum', fill_value=0).reset_index()
    pivot_df_T = comparison_df.T.reset_index().loc[3::]
    pivot_df_T['purpose'] = p
    pivot_df_T['tfn_at'] = at
    df_model = all_modelled_hh[(all_modelled_hh['purpose']==p) &(all_modelled_hh['tfn_at']==at) &(all_modelled_hh['split_method']==str(hh))]
    if not df_model.empty:
        join_model_obs = pd.concat([pivot_df_T.reset_index(), df_model.reset_index()['adjusted_rho']], axis=1)

        if len(hh)>2:
            join_model_obs = join_model_obs.rename(columns={0: 'hh_type_' + str(hh[0])})
            join_model_obs = join_model_obs.rename(columns={1: 'hh_type_' + str(hh[1])})
            join_model_obs = join_model_obs.rename(columns={2: 'hh_type_' + str(hh[2])})  
            join_model_obs = join_model_obs[['mode_period', 'hh_type_' + str(hh[0]), 'hh_type_' + str(hh[1]), 'hh_type_' + str(hh[2]), 'adjusted_rho']]
        else:    
            join_model_obs = join_model_obs.rename(columns={0: 'hh_type_' + str(hh[0])})
            join_model_obs = join_model_obs.rename(columns={1: 'hh_type_' + str(hh[1])})
            join_model_obs = join_model_obs[['mode_period', 'hh_type_' + str(hh[0]), 'hh_type_' + str(hh[1]), 'adjusted_rho']]

        #plot the observed vs modelled
        dfm = pd.melt(join_model_obs, id_vars="mode_period", var_name="number", value_name="prob")

        sns.set(style="whitegrid")
        plt.figure(figsize=(8, 5))
        ax = sns.scatterplot(x='mode_period', y='prob', hue='number', data=dfm)
        ax = sns.lineplot(x='mode_period', y='prob', hue='number', data=dfm)
        ax.spines[['top', 'right']].set_visible(False)
        sns.move_legend(ax, bbox_to_anchor=(1, 0.5), loc='center left', frameon=False)

# %% [markdown]
# #### How many combinations has been addressed so far within observed and household type heirarchy aggregation?

# %%
combinations_left =  len(resultant_df[(resultant_df['split_needed'] == 'TBD') & (resultant_df['split_method'].isnull())])
combinations_addressed = len(resultant_df[(resultant_df['split_needed'] == 'TBD') & (resultant_df['split_method'].notnull())])
total_combinations = len(resultant_df)
observed_split = len(resultant_df[resultant_df['split_needed'] == 'observed'])

# %% [markdown]
# #### Statistics

# %%
print("Total combinations:", total_combinations)
print("Total combinations addressed by observed split:", observed_split)
print("Total combinations addressed by household type hierarchy:", combinations_addressed)
print("Total combinations still to be addressed by TfN area type:", combinations_left)

print("% combinations addressed by observed split:", observed_split/total_combinations*100)
print("% combinations addressed by household type hierarchy:", combinations_addressed/total_combinations*100)
print("% combinations still to be addressed by TfN area type:", combinations_left/total_combinations*100)
# Out:
# Total combinations: 53760
# Total combinations addressed by observed split: 39396
# Total combinations addressed by household type hierarchy: 8484
# Total combinations still to be addressed by TfN area type: 5880
# % combinations addressed by observed split: 73.28125
# % combinations addressed by household type hierarchy: 15.78125
# % combinations still to be addressed by TfN area type: 10.9375

# %% [markdown]
# ## Full Model Build

# %% [markdown]
# ### Model build with Household type and TfN area type aggregation hierarchies

# %% [markdown]
# - Apply the model to combinations with trip samples for the combined aggregation less than 500, aggregation by household type and TfN area type.

# %% [markdown]
# ### TfN Area Type Aggregations

# %% [markdown]
# #### Rationale for choosing the new TfN aggregations.
#
# - Firstly, we reviewed TfN Area Type aggregations that were used previously. There were separate groupings for London, Major & Minor, Cities by geographical split and Rural as these result in different trip distributions across modes and time due to the nature of the area types. These aggregation categories should be retained.
#
# - The additional new area types included categories such as Town and Scotland.
#
# - Next we reviewed the WP1 area type groupings analysis, it was determined that v1 of the groupings was closer to the original aggregations set. In this grouping, Town, Rural and Scotland area types were all grouped separately whilst all Cities were aggregated together and Major & Minor plus London were aggregated together.
#
# - Therefore, we have used a combination of the existing area type grouping definitions and aggregations explored by WP1 for brand new defined area types to produce the following TfN area type groupings:
#
#     - London - 1,2
#     - Major and Minor - 3,4,5,6,7,8
#     - City South -  9,10,11
#     - City Midland - 12,13
#     - City North - 14,15
#     - Town - 16,17
#     - Rural - 18,19
#     - Scotland - 20
#
# These groupings can be amended manually by updating the dictionary in the cell below.

# %%
df_trip_join = df_trip_join.fillna(0) #ensure that the target variable y (splits) always has a value
audit_df = pd.DataFrame(columns = ['purpose', 'area_type','agg', 'total_trips', 'status'])

#define aggregation hierarchies for household type and new TfN area type
tfn_at = {1: [1, 2], 2: [1, 2], 3: [3, 4, 5, 6, 7, 8], 4: [3, 4, 5, 6, 7, 8], 5: [3, 4, 5, 6, 7, 8], 6: [3, 4, 5, 6, 7, 8], 7: [3, 4, 5, 6, 7, 8], 8: [3, 4, 5, 6, 7, 8], 
          9: [9, 10, 11], 10: [9, 10, 11], 11: [9, 10, 11], 12: [12, 13], 13: [12, 13], 14: [14, 15], 15: [14, 15], 16: [16, 17],  
          17: [16, 17],18: [18, 19] ,19: [18, 19], 20: [20]}
list_hh_type = [[1,3,6], [2,5,8], [4,7]]
modelled_df = pd.DataFrame()
modelled_at = pd.DataFrame()
for p in range(1,9):
    for at in range (1,21):
        df_mode_period_join_f = df_trip_join[(df_trip_join['purpose']==p) &(df_trip_join['tfn_at']==at)]
        for hh in list_hh_type:
            df_mode_period_join_hh = df_mode_period_join_f[df_mode_period_join_f.hh_type.isin(hh)]
            needs_pred = df_mode_period_join_hh[df_mode_period_join_hh.split_method == 'TBD']
            trips = df_mode_period_join_hh.total_trips.unique().sum()
            
            if not needs_pred.empty:
                if trips > 500:
                    data_df = [[p, at, hh, trips, 'Need hh_type aggregation']]
                    audit_df = audit_df.append(pd.Series(data_df[0], index=audit_df.columns), ignore_index=True)
                    if not needs_pred.empty:
                        X_train_cat = df_mode_period_join_hh[['purpose', 'tfn_at','mode_period']]
                        X_train_prob = df_mode_period_join_hh[['split']]

                        # Encode categorical features using one-hot encoding
                        encoder = OneHotEncoder(sparse_output=False)
                        X = encoder.fit_transform(X_train_cat)

                        y = X_train_prob['split'].reset_index()
                        y = np.array([y['split']]).T

                        # Initialize and train the model
                        model = LinearRegression()
                        model.fit(X, y)

                        X_predictor = encoder.fit_transform(X_train_cat.drop_duplicates())
                        y_predicted_new_data = model.predict(X_predictor)

                        m_p = X_train_cat.drop_duplicates()[['mode_period']]

                        df_predict = pd.DataFrame(y_predicted_new_data)
                        df_model = df_predict.rename(columns={0: 'modelled'})
                        df_model = df_model.clip(lower = 0)

                        df_model['purpose'] = p
                        df_model['tfn_at'] = at
                        df_model = df_model.reset_index()
                        m_p = m_p.reset_index()
                        df_model['mode_period'] = m_p['mode_period']
                        # store DataFrame in list
                        df_model['split_method'] =str(hh)
                        #store df 
                        modelled_df= pd.concat([modelled_df, df_model])    
                else:
                    if not needs_pred.empty:
                        data_df = [[p, at, hh, trips, 'Need tfn_at aggregation']]
                        audit_df = audit_df.append(pd.Series(data_df[0], index=audit_df.columns), ignore_index=True)
                        df_mode_period_join_at = df_trip_join[(df_trip_join['purpose']==p)]
                        df_mode_period_join_at = df_mode_period_join_at[df_mode_period_join_at.tfn_at.isin(tfn_at[at])] 
                        df_mode_period_join_at = df_mode_period_join_at[df_mode_period_join_at.hh_type.isin(hh)]
                        X_train_cat = df_mode_period_join_at[['purpose','mode_period']]
                        X_train_prob = df_mode_period_join_at[['split']]

                        # Encode categorical features using one-hot encoding
                        encoder = OneHotEncoder(sparse_output=False)
                        X = encoder.fit_transform(X_train_cat)

                        y = X_train_prob['split'].reset_index()
                        y = np.array([y['split']]).T

                        # Initialize and train the model
                        model = LinearRegression()
                        model.fit(X, y)

                        X_predictor = encoder.fit_transform(X_train_cat.drop_duplicates())
                        y_predicted_new_data = model.predict(X_predictor)

                        m_p = X_train_cat.drop_duplicates()[['mode_period']]

                        df_predict = pd.DataFrame(y_predicted_new_data)
                        df_model = df_predict.rename(columns={0: 'modelled'})
                        df_model = df_model.clip(lower = 0)

                        df_model['purpose'] = p
                        df_model['hh'] = str(hh)
                        df_model = df_model.reset_index()
                        m_p = m_p.reset_index()
                        df_model['mode_period'] = m_p['mode_period']
                        # store DataFrame in list
                        df_model['split_method'] =str(tfn_at[at])

                        #store df 
                        modelled_at= pd.concat([modelled_at, df_model])
                        modelled_at = modelled_at.drop_duplicates()
            else:
                data_df = [[p, at, hh, trips, 'No aggregation all hh types above 500 trips individually']]
                audit_df = audit_df.append(pd.Series(data_df[0], index=audit_df.columns), ignore_index=True)
                    
#add column describing the method used to derive the splits
modelled_df['modelled'] = modelled_df['modelled'].clip(lower = 0)
modelled_df = modelled_df[['mode_period','purpose', 'tfn_at','modelled', 'split_method']]
modelled_df =modelled_df.assign(hh_type=modelled_df['split_method'].str.strip('[]').str.split(',')).explode('hh_type').reset_index(drop=True)
modelled_df.hh_type = modelled_df.hh_type.astype(int)
modelled_df_groupby = modelled_df.groupby(['purpose','tfn_at','hh_type']).sum().rename(columns={'modelled': 'sum of modelled'}).reset_index()

#constraining the mts to 1 to created the adjusted rho column
all_modelled_hh = pd.merge(modelled_df, modelled_df_groupby, how='inner', on = ['purpose','tfn_at','hh_type'])
all_modelled_hh['adjusted_rho'] = all_modelled_hh['modelled'] / all_modelled_hh['sum of modelled']
all_modelled_hh = all_modelled_hh[['mode_period','purpose','tfn_at', 'hh_type', 'split_method', 'adjusted_rho']]
all_modelled_hh = all_modelled_hh.fillna(0)
all_modelled_hh = all_modelled_hh.drop_duplicates()

#add column describing the method used to derive the splits
modelled_at['modelled'] = modelled_at['modelled'].clip(lower = 0)
modelled_df = modelled_at[['mode_period','purpose', 'hh','modelled', 'split_method']]
modelled_df =modelled_df.assign(tfn_at=modelled_df['split_method'].str.strip('[]').str.split(',')).explode('tfn_at').reset_index(drop=True)
modelled_df.tfn_at = modelled_df.tfn_at.astype(int)
modelled_df =modelled_df.assign(hh_type=modelled_df['hh'].str.strip('[]').str.split(',')).explode('hh_type').reset_index(drop=True)
modelled_df.hh_type = modelled_df.hh_type.astype(int)
modelled_df_groupby = modelled_df.groupby(['purpose','tfn_at','hh_type']).sum().rename(columns={'modelled': 'sum of modelled'}).reset_index()

#constraining the mts to 1 to created the adjusted rho column
all_modelled_at = pd.merge(modelled_df, modelled_df_groupby, how='inner', on = ['purpose','tfn_at','hh_type'])
all_modelled_at['adjusted_rho'] = all_modelled_at['modelled'] / all_modelled_at['sum of modelled']
all_modelled_at = all_modelled_at[['mode_period','purpose','tfn_at','hh_type', 'split_method', 'adjusted_rho']]
all_modelled_at = all_modelled_at.fillna(0)
all_modelled_at = all_modelled_at.drop_duplicates()

#create the split column that defined which hh type agg method would be needed
df_trip_join_hh = df_trip_join[['purpose','tfn_at','mode_period','hh_type', 'split', 'split_method']]
df_trip_join_hh = df_trip_join_hh[df_trip_join_hh.split_method == 'TBD']
df_trip_join_hh = df_trip_join_hh.rename(columns={'split_method': 'split_needed'})

df_trip_join_ob = df_trip_join[['purpose','tfn_at','mode_period','hh_type', 'split', 'split_method']]
df_trip_join_ob = df_trip_join_ob[df_trip_join_ob.split_method == 'observed']
df_trip_join_ob = df_trip_join_ob.rename(columns={'split_method': 'split_needed'})

#merge the observed and modelled information together into a final dataframe
resultant_df_hh = pd.merge(df_trip_join_hh, all_modelled_hh, left_on=['purpose', 'tfn_at','mode_period','hh_type'], right_on=['purpose', 'tfn_at','mode_period','hh_type'], how = 'left')
resultant_df_at = resultant_df_hh[resultant_df_hh.split_method.isnull()]
resultant_df_hh = resultant_df_hh[resultant_df_hh.split_method.notnull()]
resultant_df_at = resultant_df_at[['purpose','tfn_at','mode_period','hh_type','split', 'split_needed']]
resultant_df_2 = pd.merge(resultant_df_at, all_modelled_at, left_on=['purpose', 'tfn_at','mode_period','hh_type'], right_on=['purpose', 'tfn_at','mode_period','hh_type'], how = 'left')
resultant_df = pd.concat([resultant_df_hh,resultant_df_2])
resultant_df_final = pd.concat([resultant_df, df_trip_join_ob])

resultant_df_final['split_final'] = np.where(resultant_df_final['split_needed'] == 'TBD', resultant_df_final['adjusted_rho'], resultant_df_final['split'])

resultant_df_final = resultant_df_final.drop_duplicates()
resultant_df_final.to_csv('mts_output.csv')
audit_df.to_csv('all_audit_output.csv')
resultant_df_final
# Out:
# C:\Users\SIMC2320\AppData\Local\Temp\ipykernel_25756\2655472644.py:99: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   audit_df = audit_df.append(pd.Series(data_df[0], index=audit_df.columns), ignore_index=True)
# C:\Users\SIMC2320\AppData\Local\Temp\ipykernel_25756\2655472644.py:99: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   audit_df = audit_df.append(pd.Series(data_df[0], index=audit_df.columns), ignore_index=True)
# C:\Users\SIMC2320\AppData\Local\Temp\ipykernel_25756\2655472644.py:99: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   audit_df = audit_df.append(pd.Series(data_df[0], index=audit_df.columns), ignore_index=True)
# ...

# %%
audit_df
# Out:
#     purpose area_type        agg   total_trips  \
# 0         1         1  [1, 3, 6]  16524.119459
# 1         1         1  [2, 5, 8]   4636.856237
# 2         1         1     [4, 7]  10553.461190
# 3         1         2  [1, 3, 6]   8607.767941
# 4         1         2  [2, 5, 8]  20339.344903
# ..      ...       ...        ...           ...
# 475       8        19  [2, 5, 8]   6601.422512
# 476       8        19     [4, 7]   1623.375816
# 477       8        20  [1, 3, 6]    387.973258
# 478       8        20  [2, 5, 8]   1370.043351
# 479       8        20     [4, 7]    986.608748
#
#                                                 status
# 0    No aggregation all hh types above 500 trips in...
# 1    No aggregation all hh types above 500 trips in...
# 2    No aggregation all hh types above 500 trips in...
# 3    No aggregation all hh types above 500 trips in...
# 4    No aggregation all hh types above 500 trips in...
# ..                                                 ...
# ...

# %% [markdown]
# #### Visualisations of the model to evaluate performance (household type aggregation)

# %%
p=1
at=3
list_hh_type = [[1,3,6], [2,5,8], [4,7]]
for hh in list_hh_type:
    df_hh = df_trip_join[df_trip_join.hh_type.isin(hh)]
    df_mode_period_join_f = df_hh[(df_hh['purpose']==p) &(df_hh['tfn_at']==at)]
    #create the dataframe which has the observed splits to compare against
    comparison_df = df_mode_period_join_f.pivot_table(index=['purpose','tfn_at','hh_type'], columns='mode_period', values='split', aggfunc='sum', fill_value=0).reset_index()
    pivot_df_T = comparison_df.T.reset_index().loc[3::]
    pivot_df_T['purpose'] = p
    pivot_df_T['tfn_at'] = at
    df_model = all_modelled_hh[(all_modelled_hh['purpose']==p) &(all_modelled_hh['tfn_at']==at) &(all_modelled_hh['split_method']==str(hh))]
    if not df_model.empty:
        join_model_obs = pd.concat([pivot_df_T.reset_index(), df_model.reset_index()['adjusted_rho']], axis=1)

        if len(hh)>2:
            join_model_obs = join_model_obs.rename(columns={0: 'hh_type_' + str(hh[0])})
            join_model_obs = join_model_obs.rename(columns={1: 'hh_type_' + str(hh[1])})
            join_model_obs = join_model_obs.rename(columns={2: 'hh_type_' + str(hh[2])})  
            join_model_obs = join_model_obs[['mode_period', 'hh_type_' + str(hh[0]), 'hh_type_' + str(hh[1]), 'hh_type_' + str(hh[2]), 'adjusted_rho']]
        else:    
            join_model_obs = join_model_obs.rename(columns={0: 'hh_type_' + str(hh[0])})
            join_model_obs = join_model_obs.rename(columns={1: 'hh_type_' + str(hh[1])})
            join_model_obs = join_model_obs[['mode_period', 'hh_type_' + str(hh[0]), 'hh_type_' + str(hh[1]), 'adjusted_rho']]

        #plot the observed vs modelled
        dfm = pd.melt(join_model_obs, id_vars="mode_period", var_name="number", value_name="prob")

        sns.set(style="whitegrid")
        plt.figure(figsize=(8, 5))
        ax = sns.scatterplot(x='mode_period', y='prob', hue='number', data=dfm)
        ax = sns.lineplot(x='mode_period', y='prob', hue='number', data=dfm)
        ax.spines[['top', 'right']].set_visible(False)
        sns.move_legend(ax, bbox_to_anchor=(1, 0.5), loc='center left', frameon=False)

# %% [markdown]
# #### Visualisations of the model to evaluate performance (tfn area type aggregation)

# %%
df_hh = df_trip_join[df_trip_join.tfn_at.isin([16,17])]
df_mode_period_join_f = df_hh[(df_hh['purpose']==8) &(df_hh['hh_type']==3)]
#create the dataframe which has the observed splits to compare against
comparison_df = df_mode_period_join_f.pivot_table(index=['purpose','tfn_at','hh_type'], columns='mode_period', values='split', aggfunc='sum', fill_value=0).reset_index()
pivot_df_T = comparison_df.T.reset_index().loc[3::]
pivot_df_T['purpose'] = 8
pivot_df_T['hh_type'] = 3
df_model = all_modelled_at[(all_modelled_at['purpose']==8) &(all_modelled_at['hh_type']==3) &(all_modelled_at['split_method']==str([16,17]))]
    
if not df_model.empty:
    join_model_obs = pd.concat([pivot_df_T.reset_index(), df_model.reset_index()['adjusted_rho']], axis=1)
    join_model_obs = join_model_obs.rename(columns={0: 'area_type_' + str(16)})
    join_model_obs = join_model_obs.rename(columns={1: 'area_type_' + str(17)})
    join_model_obs = join_model_obs[['mode_period', 'area_type_' + str(16), 'area_type_' + str(17), 'adjusted_rho']]

    #plot the observed vs modelled
    dfm = pd.melt(join_model_obs, id_vars="mode_period", var_name="number", value_name="prob")

    sns.set(style="whitegrid")
    plt.figure(figsize=(8, 5))
    ax = sns.scatterplot(x='mode_period', y='prob', hue='number', data=dfm)
    ax = sns.lineplot(x='mode_period', y='prob', hue='number', data=dfm)
    ax.spines[['top', 'right']].set_visible(False)
    sns.move_legend(ax, bbox_to_anchor=(1, 0.5), loc='center left', frameon=False)

# %% [markdown]
# ## Future Improvements
#
# A potential improvement is to wrap commonly used sections of the code (model build, fitting and prediction code, post-processing) into functions to streamline the codebase, enable code reuse and to avoid additional effort in codebase management.
